# %% [markdown]
# ## 코스피 정보 출력

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

# 한글 폰트 설정 (NanumGothic) 
mpl.rcParams['font.family'] = 'NanumGothic'

# %%
# API 사용
import FinanceDataReader as fdr
symbol_kospi = fdr.DataReader('KS11', '2023')
symbol_kospi
# Out:
#                Open     High      Low    Close     Volume  Change  UpDown  \
# Date
# 2023-01-02  2249.95  2259.88  2222.37  2225.67  346344799 -0.0048       2
# 2023-01-03  2230.98  2230.98  2180.67  2218.68  410245325 -0.0031       2
# 2023-01-04  2205.98  2260.06  2198.82  2255.98  412841149  0.0168       1
# 2023-01-05  2268.20  2281.39  2252.97  2264.65  430977022  0.0038       1
# 2023-01-06  2253.40  2300.62  2253.27  2289.97  398606581  0.0112       1
# ...             ...      ...      ...      ...        ...     ...     ...
# 2024-12-13  2473.75  2500.32  2470.24  2494.46  577737398  0.0050       1
# 2024-12-16  2511.08  2515.62  2483.43  2488.97  526708153 -0.0022       2
# 2024-12-17  2487.31  2487.31  2455.05  2456.81  559039721 -0.0129       2
# 2024-12-18  2463.06  2492.00  2462.82  2484.43  441677820  0.0112       1
# 2024-12-19  2426.55  2450.05  2423.59  2449.65  304829791 -0.0140       2
#
#              Comp         Amount            MarCap
# Date
# 2023-01-02 -10.73  5200137586818  1759241799519040
# 2023-01-03  -6.99  6149082624890  1753771077018843
# 2023-01-04  37.30  6487597995523  1783808765569816
# 2023-01-05   8.67  7521178466245  1791816776272757
# 2023-01-06  25.32  6764112169245  1811418923114710
# ...           ...            ...               ...
# 2024-12-13  12.34  8849455236945  2042115883546408
# 2024-12-16  -5.49  8466421567755  2037825063390027
# 2024-12-17 -32.16  9284835596090  2010343832541547
# 2024-12-18  27.62  8338565732727  2033135712509950
# 2024-12-19 -34.78  4776229712048  2004612410628103
#
# [483 rows x 10 columns]

# %%
type(symbol_kospi)
# Out:
# pandas.core.frame.DataFrame

# %%
symbol_kospi.info
# Out:
# <bound method DataFrame.info of                Open     High      Low    Close     Volume  Change  UpDown  \
# Date
# 2023-01-02  2249.95  2259.88  2222.37  2225.67  346344799 -0.0048       2
# 2023-01-03  2230.98  2230.98  2180.67  2218.68  410245325 -0.0031       2
# 2023-01-04  2205.98  2260.06  2198.82  2255.98  412841149  0.0168       1
# 2023-01-05  2268.20  2281.39  2252.97  2264.65  430977022  0.0038       1
# 2023-01-06  2253.40  2300.62  2253.27  2289.97  398606581  0.0112       1
# ...             ...      ...      ...      ...        ...     ...     ...
# 2024-12-13  2473.75  2500.32  2470.24  2494.46  577737398  0.0050       1
# 2024-12-16  2511.08  2515.62  2483.43  2488.97  526708153 -0.0022       2
# 2024-12-17  2487.31  2487.31  2455.05  2456.81  559039721 -0.0129       2
# 2024-12-18  2463.06  2492.00  2462.82  2484.43  441677820  0.0112       1
# 2024-12-19  2426.55  2450.05  2423.59  2449.65  304829791 -0.0140       2
#
#              Comp         Amount            MarCap
# Date
# 2023-01-02 -10.73  5200137586818  1759241799519040
# 2023-01-03  -6.99  6149082624890  1753771077018843
# 2023-01-04  37.30  6487597995523  1783808765569816
# 2023-01-05   8.67  7521178466245  1791816776272757
# 2023-01-06  25.32  6764112169245  1811418923114710
# ...           ...            ...               ...
# 2024-12-13  12.34  8849455236945  2042115883546408
# 2024-12-16  -5.49  8466421567755  2037825063390027
# 2024-12-17 -32.16  9284835596090  2010343832541547
# 2024-12-18  27.62  8338565732727  2033135712509950
# 2024-12-19 -34.78  4776229712048  2004612410628103
#
# [483 rows x 10 columns]>

# %%
symbol_kospi.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count   483.000000   483.000000   483.000000   483.000000  4.830000e+02
# mean   2569.337950  2581.382878  2553.778841  2567.206480  5.136371e+08
# std     121.793365   120.516411   122.523488   121.565482  1.485238e+08
# min    2205.980000  2230.980000  2180.670000  2218.680000  2.406750e+08
# 25%    2480.795000  2492.530000  2465.490000  2481.075000  4.084861e+08
# 50%    2570.240000  2582.000000  2555.460000  2567.550000  4.841884e+08
# 75%    2650.025000  2660.580000  2631.370000  2647.350000  5.926322e+08
# max    2888.760000  2896.430000  2879.280000  2891.350000  1.089216e+09
#
#            Change      UpDown        Comp        Amount        MarCap
# count  483.000000  483.000000  483.000000  4.830000e+02  4.830000e+02
# mean     0.000249    1.476190    0.441511  1.020373e+13  2.065615e+15
# std      0.011105    0.499951   28.444291  2.724728e+12  1.172968e+14
# min     -0.087700    1.000000 -234.640000  4.776230e+12  1.753771e+15
# 25%     -0.006100    1.000000  -15.545000  8.385362e+12  1.986032e+15
# 50%      0.000400    1.000000    1.100000  9.811877e+12  2.050228e+15
# 75%      0.006500    2.000000   17.385000  1.154978e+13  2.153335e+15
# max      0.056600    2.000000  134.030000  3.634821e+13  2.363627e+15

# %% [markdown]
# ### 꺾은 선 그래프 표시

# %%
plt.figure(figsize=(10,6), dpi = 100)

plt.plot(symbol_kospi['Close'], label='Close')
plt.plot(symbol_kospi['Open'], label = 'Open')


plt.title('2023년 이후 코스피 지수')
plt.xlabel('날짜')
plt.ylabel('지수')
plt.legend()
plt.show()

# %% [markdown]
# ### 지수화(indexing)

# %%
import numpy as np

# %%
array_first = np.array([10, 20, 30])
array_second = np.array([1000, 2000, 3000])

# %%
(array_first / array_first[0]) * 100
# Out:
# array([100., 200., 300.])

# %%
(array_second / array_second[0]) * 100
# Out:
# array([100., 200., 300.])

# %%
symbol_tway = fdr.DataReader(symbol='091810', start = '2021', end='2022')
symbol_samsung = fdr.DataReader(symbol='005930', start = '2021', end='2022')

# %%
symbol_tway.shape, symbol_samsung.shape
# Out:
# ((248, 6), (248, 6))

# %%
plt.plot(symbol_samsung.index , symbol_samsung['Close'])
plt.plot(symbol_tway.index , symbol_tway['Close'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#type(symbol_samsung['Close'])
#symbol_samsung['Close']
symbol_samsung['Close'] / symbol_samsung['Close'].iloc[0] * 100
# Out:
# Date
# 2021-01-04    100.000000
# 2021-01-05    101.084337
# 2021-01-06     99.036145
# 2021-01-07     99.879518
# 2021-01-08    106.987952
#                  ...
# 2021-12-24     96.987952
# 2021-12-27     96.626506
# 2021-12-28     96.746988
# 2021-12-29     94.939759
# 2021-12-30     94.337349
# Name: Close, Length: 248, dtype: float64

# %%
series_tway = (symbol_tway['Close'] / symbol_tway['Close'].iloc[0]) * 100
series_samsung = (symbol_samsung['Close'] / symbol_samsung['Close'].iloc[0]) * 100
series_tway
# Out:
# Date
# 2021-01-04    100.000000
# 2021-01-05    103.208791
# 2021-01-06    102.813187
# 2021-01-07    104.043956
# 2021-01-08    104.219780
#                  ...
# 2021-12-24    125.450549
# 2021-12-27    125.450549
# 2021-12-28    125.230769
# 2021-12-29    128.043956
# 2021-12-30    129.274725
# Name: Close, Length: 248, dtype: float64

# %%
plt.plot(symbol_samsung.index , series_samsung)
plt.plot(symbol_tway.index , series_tway)
plt.title('지수화 비교')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
